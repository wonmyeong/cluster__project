# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib import font_manager, rc
import platform
plt.rcParams['axes.unicode_minus'] = False
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
os.chdir('C:\\Users\\won\\teamproject\\마스크팩\\positive_keywords_tf\\pos_ref')
for i in range(0,5):
    df=pd.read_csv('pos마스크팩'+str(i)+'keywords_ref.csv',encoding='cp949')
    plt.title(df['prod_name'][0])
    plt.pie(df['word_cnt'],labels=df['word'],autopct='%.1f%%')
    plt.savefig('C:\\Users\\won\\teamproject\\charimg'+'./마스크팩'+str(i)+'.png')
    plt.show()
    plt.close()

# %%
df['prod_name'][0]
# Out:
# '[단독기획] 메디힐 콜라겐 에센셜 마스크 10+1매 기획'
